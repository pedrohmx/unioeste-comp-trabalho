# %%
from slr_parser.slr_parser import Grammar, SLRParser

PATH = '/home/xavier/Workspaces/unioeste/unioeste-comp/trabalho/specs/grammar.txt'
G = Grammar(open(PATH).read())
parser = SLRParser(G)

# %%
parser.print_info()
# Out:
# AUGMENTED GRAMMAR:
#  0:       PROG' -> PROG
#  1:        PROG -> STMTS
#  2:       STMTS -> ^
#  3:       STMTS -> STMTS STMT
#  4:        STMT -> FLOW
#  5:        STMT -> DECL_STMT ;
#  6:        STMT -> COMMAND ;
#  7:        STMT -> ATTRIB_STMT ;
#  8:   DECL_STMT -> type id DECL_END
#  9:    DECL_END -> attrib EXPR
# 10:    DECL_END -> ^
# 11: ATTRIB_STMT -> id ATTRIB_END
# 12:  ATTRIB_END -> attrib EXPR
# 13:  ATTRIB_END -> attrib_op EXPR
# 14:        EXPR -> ARITH_EXPR
# 15:        EXPR -> BOOL_EXPR
# 16:   BOOL_EXPR -> VAR bool_op VAR
# 17:   BOOL_EXPR -> REL_EXPR
# 18:   BOOL_EXPR -> not VAR
# 19:  ARITH_EXPR -> VAR arith_op_sum VAR
# 20:  ARITH_EXPR -> VAR arith_op_mul VAR
# 21:    REL_EXPR -> VAR rel_op VAR
# 22:        FLOW -> IF_STMT
# 23:        FLOW -> FOR_STMT
# 24:        FLOW -> WHILE_STMT
# 25:     IF_STMT -> if ( BOOL_EXPR ) { STMTS } ELSE_STMT
# 26:   ELSE_STMT -> ^
# 27:   ELSE_STMT -> else { STMTS }
# 28:  WHILE_STMT -> while ( BOOL_EXPR ) { STMTS }
# ...
